# %% [markdown]
# Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, BatchNormalization
from tqdm import tqdm
import time
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %% [markdown]
# define data path

# %%
data_path = r'C:\Users\cheng\OneDrive\Desktop\4012\data\4012image'

# %% [markdown]
# Loading the Data

# %%
class_names = ['mountain', 'buildings']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (150, 150)

# %%
def load_data():
    datasets= [os.path.join(data_path,'seg_train/seg_train'), os.path.join(data_path,'seg_test/seg_test')]
    output = []
    
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
datasets= [os.path.join(data_path,'seg_train/seg_train'), os.path.join(data_path,'seg_test/seg_test')]
datasets
# Out:
# ['C:\\Users\\cheng\\OneDrive\\Desktop\\4012\\data\\4012image\\seg_train/seg_train',
#  'C:\\Users\\cheng\\OneDrive\\Desktop\\4012\\data\\4012image\\seg_test/seg_test']

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
#   0%|                                                                                         | 0/2191 [00:00<?, ?it/s]
# Loading C:\Users\cheng\OneDrive\Desktop\4012\data\4012image\seg_train/seg_train
# 100%|█████████████████████████████████████████████████████████████████████████████| 2191/2191 [00:03<00:00, 636.07it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 2512/2512 [00:03<00:00, 826.13it/s]
#  26%|████████████████████▍                                                          | 113/437 [00:00<00:00, 582.53it/s]
# Loading C:\Users\cheng\OneDrive\Desktop\4012\data\4012image\seg_test/seg_test
# 100%|███████████████████████████████████████████████████████████████████████████████| 437/437 [00:00<00:00, 711.25it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 525/525 [00:00<00:00, 821.95it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %% [markdown]
# Looking to the detail of the dataset

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 4703
# Number of testing examples: 962
# Each image is of size: (150, 150)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            ).plot.bar()
plt.show()

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %%
 """
 Optional Display a random image from the images array and its correspond label from the labels array.
 """
def display_random_image(class_names, images, labels):
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %% [markdown]
# Show random images from the dataset

# %%
display_random_image(class_names, train_images, train_labels)

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()
    
display_examples(class_names, train_images, train_labels)

# %% [markdown]
# configure the hyperparameters of the model

# %%
tf.random.set_seed(0)

#MLP
model = Sequential()

model.add(Flatten())
model.add(Dense(64,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(128,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(128,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(64,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(32,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(1,activation="sigmoid"))

model.compile(loss='binary_crossentropy', optimizer = 'adam', metrics= ['accuracy'])
start_time = time.time()
history = model.fit(train_images, train_labels, batch_size=128, epochs=100, validation_split = 0.2)
end_time = time.time()
train_time = end_time - start_time
# Out:
# Epoch 1/100
# 30/30 [==============================] - 3s 40ms/step - loss: 0.6594 - accuracy: 0.6613 - val_loss: 0.6269 - val_accuracy: 0.6376
# Epoch 2/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.4511 - accuracy: 0.7904 - val_loss: 0.7451 - val_accuracy: 0.4995
# Epoch 3/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.3849 - accuracy: 0.8269 - val_loss: 0.6650 - val_accuracy: 0.5866
# Epoch 4/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.3428 - accuracy: 0.8534 - val_loss: 0.6046 - val_accuracy: 0.6695
# Epoch 5/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.2746 - accuracy: 0.8796 - val_loss: 0.6184 - val_accuracy: 0.6610
# Epoch 6/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.2192 - accuracy: 0.9150 - val_loss: 0.4917 - val_accuracy: 0.7779
# Epoch 7/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1847 - accuracy: 0.9240 - val_loss: 0.6093 - val_accuracy: 0.7365
# Epoch 8/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1496 - accuracy: 0.9483 - val_loss: 0.5059 - val_accuracy: 0.7991
# Epoch 9/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1192 - accuracy: 0.9635 - val_loss: 0.6562 - val_accuracy: 0.7481
# Epoch 10/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0940 - accuracy: 0.9695 - val_loss: 0.7079 - val_accuracy: 0.7524
# Epoch 11/100
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0570 - accuracy: 0.9824 - val_loss: 0.6465 - val_accuracy: 0.7885
# Epoch 12/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0685 - accuracy: 0.9771 - val_loss: 0.8497 - val_accuracy: 0.7811
# Epoch 13/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0628 - accuracy: 0.9750 - val_loss: 2.5482 - val_accuracy: 0.5186
# Epoch 14/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0897 - accuracy: 0.9663 - val_loss: 0.9326 - val_accuracy: 0.7205
# Epoch 15/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0705 - accuracy: 0.9740 - val_loss: 1.3442 - val_accuracy: 0.7003
# Epoch 16/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0560 - accuracy: 0.9795 - val_loss: 2.0099 - val_accuracy: 0.5675
# Epoch 17/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0451 - accuracy: 0.9863 - val_loss: 0.8600 - val_accuracy: 0.7545
# Epoch 18/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0257 - accuracy: 0.9935 - val_loss: 2.1491 - val_accuracy: 0.5919
# Epoch 19/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0244 - accuracy: 0.9943 - val_loss: 0.8511 - val_accuracy: 0.7821
# Epoch 20/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0235 - accuracy: 0.9903 - val_loss: 0.8605 - val_accuracy: 0.7715
# Epoch 21/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0276 - accuracy: 0.9896 - val_loss: 1.2952 - val_accuracy: 0.7503
# Epoch 22/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0248 - accuracy: 0.9920 - val_loss: 0.6814 - val_accuracy: 0.8193
# Epoch 23/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0273 - accuracy: 0.9924 - val_loss: 2.3169 - val_accuracy: 0.5845
# Epoch 24/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0480 - accuracy: 0.9804 - val_loss: 1.2008 - val_accuracy: 0.7173
# Epoch 25/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0366 - accuracy: 0.9853 - val_loss: 1.3333 - val_accuracy: 0.7141
# Epoch 26/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0432 - accuracy: 0.9842 - val_loss: 1.1989 - val_accuracy: 0.7237
# Epoch 27/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0207 - accuracy: 0.9938 - val_loss: 0.8946 - val_accuracy: 0.8013
# Epoch 28/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0347 - accuracy: 0.9865 - val_loss: 1.2012 - val_accuracy: 0.7620
# Epoch 29/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0258 - accuracy: 0.9908 - val_loss: 1.1642 - val_accuracy: 0.7078
# Epoch 30/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0345 - accuracy: 0.9887 - val_loss: 1.3080 - val_accuracy: 0.7141
# Epoch 31/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0272 - accuracy: 0.9905 - val_loss: 0.9324 - val_accuracy: 0.7790
# Epoch 32/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 1.2336 - val_accuracy: 0.7003
# Epoch 33/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0179 - accuracy: 0.9934 - val_loss: 0.8198 - val_accuracy: 0.7800
# Epoch 34/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0364 - accuracy: 0.9860 - val_loss: 1.1209 - val_accuracy: 0.7928
# Epoch 35/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0437 - accuracy: 0.9846 - val_loss: 1.5603 - val_accuracy: 0.7396
# Epoch 36/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0556 - accuracy: 0.9803 - val_loss: 1.3434 - val_accuracy: 0.6865
# Epoch 37/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0252 - accuracy: 0.9899 - val_loss: 1.6116 - val_accuracy: 0.6886
# Epoch 38/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0225 - accuracy: 0.9942 - val_loss: 0.7727 - val_accuracy: 0.7864
# Epoch 39/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0138 - accuracy: 0.9959 - val_loss: 1.3562 - val_accuracy: 0.6823
# Epoch 40/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0137 - accuracy: 0.9958 - val_loss: 1.0621 - val_accuracy: 0.7800
# Epoch 41/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 1.0467 - val_accuracy: 0.7705
# Epoch 42/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0230 - accuracy: 0.9919 - val_loss: 1.4333 - val_accuracy: 0.7535
# Epoch 43/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0254 - accuracy: 0.9924 - val_loss: 1.9822 - val_accuracy: 0.5643
# Epoch 44/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 1.3253 - val_accuracy: 0.6227
# Epoch 45/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0153 - accuracy: 0.9948 - val_loss: 0.8864 - val_accuracy: 0.7736
# Epoch 46/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.9049 - val_accuracy: 0.8140
# Epoch 47/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.8165 - val_accuracy: 0.8151
# Epoch 48/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.9029 - val_accuracy: 0.8162
# Epoch 49/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.9631 - val_accuracy: 0.8045
# Epoch 50/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.8167 - val_accuracy: 0.7991
# Epoch 51/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 1.0303 - val_accuracy: 0.8023
# Epoch 52/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 1.8522 - val_accuracy: 0.6993
# Epoch 53/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0301 - accuracy: 0.9895 - val_loss: 1.3967 - val_accuracy: 0.7269
# Epoch 54/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0399 - accuracy: 0.9843 - val_loss: 1.4626 - val_accuracy: 0.6334
# Epoch 55/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0459 - accuracy: 0.9855 - val_loss: 1.2145 - val_accuracy: 0.7598
# Epoch 56/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 1.1441 - val_accuracy: 0.7938
# Epoch 57/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.9626 - val_accuracy: 0.8013
# Epoch 58/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0168 - accuracy: 0.9938 - val_loss: 1.3162 - val_accuracy: 0.7279
# Epoch 59/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.8560 - val_accuracy: 0.7917
# Epoch 60/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.9817 - val_accuracy: 0.7970
# Epoch 61/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.9943 - val_accuracy: 0.8077
# Epoch 62/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0094 - accuracy: 0.9954 - val_loss: 1.1168 - val_accuracy: 0.7917
# Epoch 63/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 1.0016 - val_accuracy: 0.7779
# Epoch 64/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 1.1308 - val_accuracy: 0.7821
# Epoch 65/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0403 - accuracy: 0.9873 - val_loss: 1.6937 - val_accuracy: 0.6791
# Epoch 66/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0175 - accuracy: 0.9938 - val_loss: 1.8723 - val_accuracy: 0.6918
# Epoch 67/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 1.1807 - val_accuracy: 0.7651
# Epoch 68/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 1.1986 - val_accuracy: 0.7641
# Epoch 69/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0047 - accuracy: 0.9973 - val_loss: 1.0914 - val_accuracy: 0.7917
# Epoch 70/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0076 - accuracy: 0.9983 - val_loss: 0.9487 - val_accuracy: 0.7960
# Epoch 71/100
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0037 - accuracy: 0.9982 - val_loss: 0.9587 - val_accuracy: 0.8183
# Epoch 72/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 1.1483 - val_accuracy: 0.7832
# Epoch 73/100
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0041 - accuracy: 0.9976 - val_loss: 0.9529 - val_accuracy: 0.8215
# Epoch 74/100
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 1.2523 - val_accuracy: 0.7428
# Epoch 75/100
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0066 - accuracy: 0.9980 - val_loss: 1.4812 - val_accuracy: 0.7269
# Epoch 76/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 2.1752 - val_accuracy: 0.6599
# Epoch 77/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 1.8713 - val_accuracy: 0.7088
# Epoch 78/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0500 - accuracy: 0.9846 - val_loss: 1.5990 - val_accuracy: 0.5845
# Epoch 79/100
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0183 - accuracy: 0.9933 - val_loss: 4.7768 - val_accuracy: 0.4655
# Epoch 80/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0307 - accuracy: 0.9883 - val_loss: 1.4654 - val_accuracy: 0.7237
# Epoch 81/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0191 - accuracy: 0.9924 - val_loss: 1.3099 - val_accuracy: 0.7396
# Epoch 82/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0140 - accuracy: 0.9967 - val_loss: 1.8053 - val_accuracy: 0.6631
# Epoch 83/100
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 1.2268 - val_accuracy: 0.7705
# Epoch 84/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 1.1306 - val_accuracy: 0.7715
# Epoch 85/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0240 - accuracy: 0.9910 - val_loss: 1.7868 - val_accuracy: 0.6716
# Epoch 86/100
# 30/30 [==============================] - 1s 35ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 1.1633 - val_accuracy: 0.7503
# Epoch 87/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 1.0338 - val_accuracy: 0.7960
# Epoch 88/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 1.3377 - val_accuracy: 0.7141
# Epoch 89/100
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.9776 - val_accuracy: 0.8055
# Epoch 90/100
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0317 - accuracy: 0.9907 - val_loss: 3.6398 - val_accuracy: 0.4431
# Epoch 91/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 1.9783 - val_accuracy: 0.5452
# Epoch 92/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 1.8983 - val_accuracy: 0.7078
# Epoch 93/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0119 - accuracy: 0.9981 - val_loss: 2.0896 - val_accuracy: 0.6961
# Epoch 94/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 1.8349 - val_accuracy: 0.7237
# Epoch 95/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0306 - accuracy: 0.9914 - val_loss: 1.1126 - val_accuracy: 0.7885
# Epoch 96/100
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0177 - accuracy: 0.9954 - val_loss: 2.4040 - val_accuracy: 0.5462
# Epoch 97/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0175 - accuracy: 0.9934 - val_loss: 3.7816 - val_accuracy: 0.5271
# Epoch 98/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0272 - accuracy: 0.9927 - val_loss: 1.2863 - val_accuracy: 0.7396
# Epoch 99/100
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 1.0946 - val_accuracy: 0.7758
# Epoch 100/100
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 1.0391 - val_accuracy: 0.7906

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 67500)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4320064
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 4,407,361
# Trainable params: 4,406,017
# Non-trainable params: 1,344
# _________________________________________________________________
# None

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(10,5))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "accuracy")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_accuracy")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %% [markdown]
# Plot the accuracy and loss of between training set and the validation set

# %%
plot_accuracy_loss(history)

# %% [markdown]
# show the accuracy of the model

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 31/31 [==============================] - 0s 5ms/step - loss: 1.0208 - accuracy: 0.7890

# %%
predictions = np.round(model.predict(test_images)).astype(int)    # Vector of probabilities
pred_labels = np.squeeze(predictions) 
display_random_image(class_names, test_images, pred_labels)

# %% [markdown]
# Print the mislabeled images

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)

# %% [markdown]
# print the confusion matrix

# %%
CM
# Out:
# array([[477,  48],
#        [155, 282]], dtype=int64)

# %% [markdown]
# print the training time

# %%
print(train_time)
# Out:
# 101.17157435417175
